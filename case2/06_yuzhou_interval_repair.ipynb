# %%
import pandas as pd

# %%
#code by chenyuzhou

# %%
df = pd.read_csv('C:/Users/chenyuzhou/Desktop/customer.csv')

# %%
df
# Out:
#        user_id  interval_2_1  interval_3_2  interval_4_3  interval_3_1  \
# 0        86499      2.911871   9999.000000        9999.0   9999.000000
# 1        86500      0.842518     17.032144        9999.0     17.874661
# 2        86501      2.952185   9999.000000        9999.0   9999.000000
# 3        86502      0.706260   9999.000000        9999.0   9999.000000
# 4        86503      1.223789   9999.000000        9999.0   9999.000000
# ...        ...           ...           ...           ...           ...
# 44083   133830   9999.000000   9999.000000        9999.0   9999.000000
# 44084   133834   9999.000000   9999.000000        9999.0   9999.000000
# 44085   133836      0.098785     14.097189        9999.0     14.195974
# 44086   133837     14.077242   9999.000000        9999.0   9999.000000
# 44087   133838     30.974825   9999.000000        9999.0   9999.000000
#
#        interval_4_1  interval_4_2  sub_interval  first_spend  third_spend  \
# ...

# %%
df['label'].value_counts()
# Out:
# no_loyal      36493
# fund_infor     3486
# infor          3478
# fund            631
# Name: label, dtype: int64

# %%
df21 = df[df.interval_2_1 != 9999.000000]

# %%
df21
# Out:
#        user_id  interval_2_1  interval_3_2  interval_4_3  interval_3_1  \
# 0        86499      2.911871   9999.000000        9999.0   9999.000000
# 1        86500      0.842518     17.032144        9999.0     17.874661
# 2        86501      2.952185   9999.000000        9999.0   9999.000000
# 3        86502      0.706260   9999.000000        9999.0   9999.000000
# 4        86503      1.223789   9999.000000        9999.0   9999.000000
# ...        ...           ...           ...           ...           ...
# 44081   133827      0.653376   9999.000000        9999.0   9999.000000
# 44082   133829     30.093320   9999.000000        9999.0   9999.000000
# 44085   133836      0.098785     14.097189        9999.0     14.195974
# 44086   133837     14.077242   9999.000000        9999.0   9999.000000
# 44087   133838     30.974825   9999.000000        9999.0   9999.000000
#
#        interval_4_1  interval_4_2  sub_interval  first_spend  third_spend  \
# ...

# %%
df.groupby('label')['interval_2_1'].median()
# Out:
# label
# fund             1.754269
# fund_infor      13.335436
# infor           30.476083
# no_loyal      1485.085033
# Name: interval_2_1, dtype: float64

# %%
df.groupby('label')['interval_3_2'].median()
# Out:
# label
# fund            13.916157
# fund_infor      21.941663
# infor          250.913708
# no_loyal      9999.000000
# Name: interval_3_2, dtype: float64

# %%
df.groupby('label')['interval_4_3'].median()
# Out:
# label
# fund            14.089667
# fund_infor      28.018163
# infor         9999.000000
# no_loyal      9999.000000
# Name: interval_4_3, dtype: float64

# %%
df21.groupby('label')['interval_2_1'].median()
# Out:
# label
# fund           1.439716
# fund_infor    13.320525
# infor         20.977450
# no_loyal       2.088215
# Name: interval_2_1, dtype: float64

# %%
df32.groupby('label')['interval_3_2'].median()
# Out:
# label
# fund          12.967361
# fund_infor    14.048382
# infor         27.039998
# no_loyal      16.002281
# Name: interval_3_2, dtype: float64

# %%
df43.groupby('label')['interval_4_3'].median()
# Out:
# label
# fund          13.572256
# fund_infor    15.000000
# infor         29.604364
# no_loyal      18.930364
# Name: interval_4_3, dtype: float64

# %%
df21['label'].value_counts()
# Out:
# no_loyal      18253
# fund_infor     3462
# infor          2560
# fund            580
# Name: label, dtype: int64

# %%
df32 = df[df.interval_3_2 != 9999.000000]

# %%
df32
# Out:
#        user_id  interval_2_1  interval_3_2  interval_4_3  interval_3_1  \
# 1        86500      0.842518     17.032144   9999.000000     17.874661
# 6        86505      0.641310      7.120142   9999.000000      7.761451
# 7        86506      0.689633     43.970446     81.862447     44.660080
# 9        86508      0.603214      6.985570   9999.000000      7.588784
# 10       86509      0.200080      9.877896   9999.000000     10.077976
# ...        ...           ...           ...           ...           ...
# 43990   133696      5.302198      7.000000      7.000000     12.302198
# 44011   133718      0.476304     13.687269   9999.000000     14.163573
# 44012   133719     11.882018     18.567528     14.000000     30.449545
# 44060   133773     23.678141      7.000000   9999.000000     30.678141
# 44085   133836      0.098785     14.097189   9999.000000     14.195974
#
#        interval_4_1  interval_4_2  sub_interval  first_spend  third_spend  \
# ...

# %%
df32['label'].value_counts()
# Out:
# no_loyal      10172
# fund_infor     2676
# infor          1871
# fund            546
# Name: label, dtype: int64

# %%
df43 = df[df.interval_4_3 != 9999.000000]

# %%
df43
# Out:
#        user_id  interval_2_1  interval_3_2  interval_4_3  interval_3_1  \
# 7        86506      0.689633     43.970446     81.862447     44.660080
# 14       86513      0.467208     10.999195     21.060489     11.466403
# 15       86514      0.521992      6.089268      6.866757      6.611260
# 27       86526      0.003758      0.462671     26.823263      0.466428
# 28       86527      0.920944     34.008433     34.093063     34.929377
# ...        ...           ...           ...           ...           ...
# 43853   133546     13.147681     14.000000     14.000000     27.147681
# 43858   133551      8.656517     10.000000      8.000000     18.656517
# 43859   133552     13.453604     14.000000     14.000000     27.453604
# 43990   133696      5.302198      7.000000      7.000000     12.302198
# 44012   133719     11.882018     18.567528     14.000000     30.449545
#
#        interval_4_1  interval_4_2  sub_interval  first_spend  third_spend  \
# ...

# %%
df43['label'].value_counts()
# Out:
# no_loyal      6518
# fund_infor    2463
# infor         1491
# fund           526
# Name: label, dtype: int64
