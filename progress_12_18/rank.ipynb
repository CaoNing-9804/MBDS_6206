# %%
import pandas as pd
import numpy as np

# %%
f = pd.read_csv('C:/Users/chenyuzhou/Desktop/final.csv')

# %%
f.columns
# Out:
# Index(['user_id', 'order_times', 'order_spend', 'total_comment', 'sub_times',
#        'voucher_times', 'cancelled', 'login', 'view_product',
#        'add_item_to_cart', 'points_added', 'view_per_login', 'item_per_view',
#        'points_per_add', 'spend_per_order', 'cluster'],
#       dtype='object')

# %%
f['cluster'].value_counts()
# Out:
# 4    15306
# 5    10977
# 1     7522
# 6     5117
# 3     1959
# 7     1540
# 2     1286
# 9      285
# 8       55
# 0       41
# Name: cluster, dtype: int64

# %%
rest=['user_id','order_times', 'order_spend', 'total_comment', 'sub_times',
       'voucher_times', 'cancelled', 'login', 'view_product',
       'add_item_to_cart', 'points_added', 'view_per_login', 'item_per_view',
       'points_per_add', 'spend_per_order', 'cluster']

# %%
df = pd.DataFrame(columns=rest)

# %%
df
# Out:
# Empty DataFrame
# Columns: [user_id, order_times, order_spend, total_comment, sub_times, voucher_times, cancelled, login, view_product, add_item_to_cart, points_added, view_per_login, item_per_view, points_per_add, spend_per_order, cluster]
# Index: []

# %%
for i in range(10):
    r= f[f['cluster']==i].mean().values
    df.loc[len(df)] = r

# %%
df
# Out:
#          user_id  order_times  order_spend  total_comment  sub_times  \
# 0  121389.585366     1.097561  1817.253415       0.000000   0.000000
# 1  118410.300984     1.225605    50.469633       0.086812   0.101037
# 2  118499.741835     1.715397    61.181913       0.461897   0.479782
# 3  115844.616641     2.124553    32.175258       0.274119   0.312404
# 4   98585.271789     3.519992    50.333551       0.048151   0.087025
# 5  115297.200055     4.325043    75.139841       0.349549   0.413501
# 6  114906.989838     6.657221   128.975695       1.320109   1.422122
# 7  106895.888312    46.003247   791.836130       5.020779   5.270779
# 8  111301.345455    65.800000  1241.810545      34.345455  35.072727
# 9   98521.505263   136.189474  2003.761474       1.642105   2.340351
#
#    voucher_times  cancelled      login  view_product  add_item_to_cart  \
# 0       0.439024   0.000000   1.902439      9.463415          2.951220
# ...

# %%
df = df.drop(columns=['user_id'])

# %%
df
# Out:
#    order_times  order_spend  total_comment  sub_times  voucher_times  \
# 0     1.097561  1817.253415       0.000000   0.000000       0.439024
# 1     1.225605    50.469633       0.086812   0.101037       0.047062
# 2     1.715397    61.181913       0.461897   0.479782       0.247278
# 3     2.124553    32.175258       0.274119   0.312404       0.088310
# 4     3.519992    50.333551       0.048151   0.087025       0.000000
# 5     4.325043    75.139841       0.349549   0.413501       0.000091
# 6     6.657221   128.975695       1.320109   1.422122       1.129764
# 7    46.003247   791.836130       5.020779   5.270779       1.012987
# 8    65.800000  1241.810545      34.345455  35.072727       7.418182
# 9   136.189474  2003.761474       1.642105   2.340351       0.270175
#
#    cancelled      login  view_product  add_item_to_cart  points_added  \
# 0   0.000000   1.902439      9.463415          2.951220      0.878049
# ...

# %%
df['population']=[41, 7522, 1286, 1959, 15306, 10977, 5117, 1540,55,285]

# %%
df
# Out:
#    order_times  order_spend  total_comment  sub_times  voucher_times  \
# 0     1.097561  1817.253415       0.000000   0.000000       0.439024
# 1     1.225605    50.469633       0.086812   0.101037       0.047062
# 2     1.715397    61.181913       0.461897   0.479782       0.247278
# 3     2.124553    32.175258       0.274119   0.312404       0.088310
# 4     3.519992    50.333551       0.048151   0.087025       0.000000
# 5     4.325043    75.139841       0.349549   0.413501       0.000091
# 6     6.657221   128.975695       1.320109   1.422122       1.129764
# 7    46.003247   791.836130       5.020779   5.270779       1.012987
# 8    65.800000  1241.810545      34.345455  35.072727       7.418182
# 9   136.189474  2003.761474       1.642105   2.340351       0.270175
#
#    cancelled      login  view_product  add_item_to_cart  points_added  \
# 0   0.000000   1.902439      9.463415          2.951220      0.878049
# ...

# %%
df.columns
# Out:
# Index(['order_times', 'order_spend', 'total_comment', 'sub_times',
#        'voucher_times', 'cancelled', 'login', 'view_product',
#        'add_item_to_cart', 'points_added', 'view_per_login', 'item_per_view',
#        'points_per_add', 'spend_per_order', 'cluster', 'population'],
#       dtype='object')

# %%
ranks=['order_times', 'order_spend', 'total_comment', 'sub_times',
       'voucher_times', 'cancelled', 'login', 'view_product',
       'add_item_to_cart', 'points_added', 'view_per_login', 'item_per_view',
       'points_per_add', 'spend_per_order']

# %%
r = df

# %%
for i in ranks:
    print('rank_',i)
# Out:
# rank_ order_times
# rank_ order_spend
# rank_ total_comment
# rank_ sub_times
# rank_ voucher_times
# rank_ cancelled
# rank_ login
# rank_ view_product
# rank_ add_item_to_cart
# rank_ points_added
# rank_ view_per_login
# rank_ item_per_view
# rank_ points_per_add
# rank_ spend_per_order

# %%
for i in ranks:    
    r['rank_',i] = r[i].rank(method="first")

# %%
r
# Out:
#    order_times  order_spend  total_comment  sub_times  voucher_times  \
# 0     1.097561  1817.253415       0.000000   0.000000       0.439024
# 1     1.225605    50.469633       0.086812   0.101037       0.047062
# 2     1.715397    61.181913       0.461897   0.479782       0.247278
# 3     2.124553    32.175258       0.274119   0.312404       0.088310
# 4     3.519992    50.333551       0.048151   0.087025       0.000000
# 5     4.325043    75.139841       0.349549   0.413501       0.000091
# 6     6.657221   128.975695       1.320109   1.422122       1.129764
# 7    46.003247   791.836130       5.020779   5.270779       1.012987
# 8    65.800000  1241.810545      34.345455  35.072727       7.418182
# 9   136.189474  2003.761474       1.642105   2.340351       0.270175
#
#    cancelled      login  view_product  add_item_to_cart  points_added  ...  \
# 0   0.000000   1.902439      9.463415          2.951220      0.878049  ...
# ...

# %%
outputpath='C:/Users/chenyuzhou/Desktop/analysis.csv'
r.to_csv(outputpath,sep=',',index=False,header=True)
